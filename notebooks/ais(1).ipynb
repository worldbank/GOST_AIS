# %%
import dask
import coiled
from dask.distributed import Client, LocalCluster, Lock, wait
from dask.utils import SerializableLock
import dask.dataframe as dd

def config_env(env_name="ais"):
    software_env_name = f"mrmaksimize/{env_name}"
    coiled.create_software_environment(
        name=software_env_name,
        #container="mrmaksimize/prefect-coiled-env:latest",
        pip=[
            #"Fiona==1.8.19",
            #"rasterio==1.2.3",
            "s3fs==2021.5.0",
            #"xarray==0.18.2",
            #"xarray-spatial==0.2.2",
            #"rioxarray==0.4.0",
            "dask==2021.7.0",
            "distributed >= 2.23.0",
            "geopandas"
            #"scikit-image==0.18.2"
        ],
        backend_options={"region": "us-east-1"})


    return True



def get_dask_client(cluster_type = 'local', n_workers = 8, processes=True, threads_per_worker=1, scheduler_mem_gb = 8, worker_mem_gb = 8):


    if cluster_type == 'local':
        try:
            client = Client('127.0.0.1:8786')
        except:   
            cluster = LocalCluster(n_workers = n_workers, 
                               processes=processes, 
                               threads_per_worker=threads_per_worker, 
                               scheduler_port=8786)

            client = Client(cluster)
    


    else:
        software = "ais"
        #config_env(software)
        cluster = coiled.Cluster(
            name='ais-cluster',
            n_workers=n_workers,
            scheduler_cpu = threads_per_worker,
            scheduler_memory = f"{str(scheduler_mem_gb)} GiB",
            worker_cpu = threads_per_worker,
            worker_memory=f"{str(worker_mem_gb)} GiB",
            #software = f"mrmaksimize/{software}"
            
            
        )

        client = Client(cluster) 
        
    client.restart()


    return client

client = get_dask_client(cluster_type = 'local', n_workers = 8, processes=True, threads_per_worker=4, scheduler_mem_gb = 16, worker_mem_gb = 16)
client
# Out:
# Output()
# Using existing cluster: 'ais-cluster'
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# /home/mrmaksim/.local/lib/python3.8/site-packages/distributed/client.py:1183: VersionMismatchWarning: Mismatched versions found
#
# +-------------+---------------+----------------+----------------+
# | Package     | client        | scheduler      | workers        |
# +-------------+---------------+----------------+----------------+
# | blosc       | None          | 1.10.2         | 1.10.2         |
# | dask        | 2021.07.0     | 2021.07.2      | 2021.07.2      |
# | distributed | 2021.07.0     | 2021.07.2      | 2021.07.2      |
# | lz4         | None          | 3.1.3          | 3.1.3          |
# | msgpack     | 0.6.2         | 1.0.2          | 1.0.2          |
# | numpy       | 1.18.4        | 1.21.1         | 1.21.1         |
# | pandas      | 1.3.0         | 1.3.1          | 1.3.1          |
# | python      | 3.8.6.final.0 | 3.8.10.final.0 | 3.8.10.final.0 |
# +-------------+---------------+----------------+----------------+
# Notes:
# -  msgpack: Variation is ok, as long as everything is above 0.6
#   warnings.warn(version_module.VersionMismatchWarning(msg[0]["warning"]))
# <Client: 'tls://10.3.191.68:8786' processes=8 threads=32, memory=128.00 GiB>

# %%
import os, sys

import numpy as np


from matplotlib import pyplot

import random
from datetime import datetime

import pandas as pd
import geopandas as gpd


# Set Full Path Here
PATH_BASE = "/.."



STORAGE_OPTS = {"secret": os.environ.get("AWS_SECRET_ACCESS_KEY"), 
                "key": os.environ.get("AWS_ACCESS_KEY_ID")}

CLUSTER_TYPE = 'remote'

pd.set_option('display.max_columns', None)


#client = get_dask_client(cluster_type = 'remote', n_workers = 8, processes=True, threads_per_worker=4, scheduler_mem_gb = 8, worker_mem_gb = 8)
client
# Out:
# <Client: 'tls://10.3.191.68:8786' processes=8 threads=32, memory=128.00 GiB>

# %%
#df = dd.read_csv(f"{PATH_BASE}/WorldBank_SAIS_globalAOI_20190101_20201231_*.csv", 
df1 = dd.read_csv(f"{PATH_BASE}_TMP/MAY2_2019_PART.csv/*", 
                 storage_options=STORAGE_OPTS, 
                 #include_path_column=True,
                 #blocksize='100mb',
                 #blocksize=None, # Specifying NONE aligns to the files 
                 parse_dates=[#'created_at', 
                              #'timestamp', 
                              #'eta'
                             ], # Don't parse dates - extra CPU
                 dtype= {'created_at': str,
                         'timestamp': str,
                         'mmsi': int,
                         'msg_type': int,
                         'latitude': float,
                         'longitude': float,
                         'speed': float,
                         'course': float,
                         'heading': float,
                         'rot': float,
                         'imo': float,
                         'name': str,
                         'call_sign': str,
                         'flag': str,
                         'draught': float,
                         'ship_and_cargo_type': float,
                         'length': float,
                         'width': float,
                         'eta': str,
                         'destination': str,
                         'status': float,
                         'maneuver': float,
                         'accuracy': float,
                         'collection_type': str,
                         'to_bow': float,
                         'to_stern': float,
                         'to_port': float,
                         'to_starboard': float})
df1.head()
# Out:
#                        created_at                timestamp       mmsi  \
# 0  2019-05-02 07:57:10.659228 UTC  2019-05-02 06:13:59 UTC  366767150
# 1  2019-05-02 08:30:26.684951 UTC  2019-05-02 07:34:24 UTC  622122005
# 2  2019-05-02 06:28:14.036435 UTC  2019-05-02 01:18:22 UTC  710026780
# 3  2019-05-02 16:15:03.708925 UTC  2019-05-02 15:28:28 UTC  636092864
# 4  2019-05-02 06:00:54.341805 UTC  2019-05-02 05:23:13 UTC  352553000
#
#    msg_type   latitude   longitude  speed  course  heading  rot  imo name  \
# 0         1  47.580923 -122.343117    0.0   107.2    179.0  0.0  NaN  NaN
# 1         1  27.943515   33.750965    0.0    84.7    135.0  0.0  NaN  NaN
# 2         1 -25.501227  -48.533733    1.3   112.4    256.0  0.0  NaN  NaN
# 3         1  -1.462267  -81.265733   17.6     3.0      5.0  0.0  NaN  NaN
# 4         1   4.373440   99.323680   10.8   118.1    116.0  0.0  NaN  NaN
#
#   call_sign flag  draught  ship_and_cargo_type  length  width  eta  \
# 0       NaN   US      NaN                  NaN     NaN    NaN  NaN
# 1       NaN   EG      NaN                  NaN     NaN    NaN  NaN
# 2       NaN   BR      NaN                  NaN     NaN    NaN  NaN
# 3       NaN   LR      NaN                  NaN     NaN    NaN  NaN
# 4       NaN   PA      NaN                  NaN     NaN    NaN  NaN
#
#   destination  status  maneuver  accuracy collection_type
# 0         NaN     0.0       0.0       1.0       satellite
# 1         NaN     0.0       0.0       0.0       satellite
# 2         NaN     0.0       0.0       0.0       satellite
# 3         NaN     0.0       0.0       0.0       satellite
# 4         NaN     0.0       0.0       1.0       satellite

# %%
#df = dd.read_csv(f"{PATH_BASE}/WorldBank_SAIS_globalAOI_20190101_20201231_*.csv", 
df2 = dd.read_csv(f"{PATH_BASE}_TMP/MAY2_PART.csv/*", 
                 storage_options=STORAGE_OPTS, 
                 #include_path_column=True,
                 #blocksize='100mb',
                 #blocksize=None, # Specifying NONE aligns to the files 
                 parse_dates=[#'created_at', 
                              #'timestamp', 
                              #'eta'
                             ], # Don't parse dates - extra CPU
                 dtype= {'created_at': str,
                         'timestamp': str,
                         'mmsi': int,
                         'msg_type': int,
                         'latitude': float,
                         'longitude': float,
                         'speed': float,
                         'course': float,
                         'heading': float,
                         'rot': float,
                         'imo': float,
                         'name': str,
                         'call_sign': str,
                         'flag': str,
                         'draught': float,
                         'ship_and_cargo_type': float,
                         'length': float,
                         'width': float,
                         'eta': str,
                         'destination': str,
                         'status': float,
                         'maneuver': float,
                         'accuracy': float,
                         'collection_type': str,
                         'to_bow': float,
                         'to_stern': float,
                         'to_port': float,
                         'to_starboard': float})
df2.head()
# Out:
#                        created_at                timestamp       mmsi  \
# 0  2020-05-02 11:39:34.657114 UTC  2020-05-02 10:31:08 UTC  310773000
# 1  2020-05-02 15:46:19.031011 UTC  2020-05-02 13:20:19 UTC  247188100
# 2  2020-05-02 21:58:16.164046 UTC  2020-05-02 21:02:54 UTC  253476000
# 3  2020-05-02 04:39:23.940515 UTC  2020-05-02 01:23:12 UTC  261536000
# 4  2020-05-02 04:19:24.636776 UTC  2020-05-02 01:40:52 UTC  310558000
#
#    msg_type   latitude   longitude  speed  course  heading   rot  imo name  \
# 0         1  19.985653 -111.613173   17.7   284.1    283.0  -6.0  NaN  NaN
# 1         1 -37.807600  149.990640   18.4    48.0     49.0 -12.0  NaN  NaN
# 2         1 -10.767813   40.549120    0.4   234.6    184.0 -14.0  NaN  NaN
# 3         3  74.110747   34.322827    2.8   230.0    222.0 -13.0  NaN  NaN
# 4         1  -2.083307  -44.113120    8.7    36.3     38.0  -6.0  NaN  NaN
#
#   call_sign flag  draught  ship_and_cargo_type  length  width  eta  \
# 0       NaN   BM      NaN                  NaN     NaN    NaN  NaN
# 1       NaN   IT      NaN                  NaN     NaN    NaN  NaN
# 2       NaN   LU      NaN                  NaN     NaN    NaN  NaN
# 3       NaN   PL      NaN                  NaN     NaN    NaN  NaN
# 4       NaN   BM      NaN                  NaN     NaN    NaN  NaN
#
#   destination  status  maneuver  accuracy collection_type  to_bow  to_stern  \
# 0         NaN     0.0       0.0       0.0       satellite     NaN       NaN
# 1         NaN     0.0       0.0       0.0       satellite     NaN       NaN
# 2         NaN     0.0       0.0       0.0       satellite     NaN       NaN
# 3         NaN     8.0       0.0       0.0       satellite     NaN       NaN
# 4         NaN     0.0       0.0       1.0       satellite     NaN       NaN
#
#    to_port  to_starboard
# 0      NaN           NaN
# 1      NaN           NaN
# 2      NaN           NaN
# 3      NaN           NaN
# 4      NaN           NaN

# %%
df3 = dd.concat([df1, df2], interleave_partitions=True)
df3.head()
# Out:
#                        created_at                timestamp       mmsi  \
# 0  2019-05-02 07:57:10.659228 UTC  2019-05-02 06:13:59 UTC  366767150
# 1  2019-05-02 08:30:26.684951 UTC  2019-05-02 07:34:24 UTC  622122005
# 2  2019-05-02 06:28:14.036435 UTC  2019-05-02 01:18:22 UTC  710026780
# 3  2019-05-02 16:15:03.708925 UTC  2019-05-02 15:28:28 UTC  636092864
# 4  2019-05-02 06:00:54.341805 UTC  2019-05-02 05:23:13 UTC  352553000
#
#    msg_type   latitude   longitude  speed  course  heading  rot  imo name  \
# 0         1  47.580923 -122.343117    0.0   107.2    179.0  0.0  NaN  NaN
# 1         1  27.943515   33.750965    0.0    84.7    135.0  0.0  NaN  NaN
# 2         1 -25.501227  -48.533733    1.3   112.4    256.0  0.0  NaN  NaN
# 3         1  -1.462267  -81.265733   17.6     3.0      5.0  0.0  NaN  NaN
# 4         1   4.373440   99.323680   10.8   118.1    116.0  0.0  NaN  NaN
#
#   call_sign flag  draught  ship_and_cargo_type  length  width  eta  \
# 0       NaN   US      NaN                  NaN     NaN    NaN  NaN
# 1       NaN   EG      NaN                  NaN     NaN    NaN  NaN
# 2       NaN   BR      NaN                  NaN     NaN    NaN  NaN
# 3       NaN   LR      NaN                  NaN     NaN    NaN  NaN
# 4       NaN   PA      NaN                  NaN     NaN    NaN  NaN
#
#   destination  status  maneuver  accuracy collection_type  to_bow  to_stern  \
# 0         NaN     0.0       0.0       1.0       satellite     NaN       NaN
# 1         NaN     0.0       0.0       0.0       satellite     NaN       NaN
# 2         NaN     0.0       0.0       0.0       satellite     NaN       NaN
# 3         NaN     0.0       0.0       0.0       satellite     NaN       NaN
# 4         NaN     0.0       0.0       1.0       satellite     NaN       NaN
#
#    to_port  to_starboard
# 0      NaN           NaN
# 1      NaN           NaN
# 2      NaN           NaN
# 3      NaN           NaN
# 4      NaN           NaN

# %%
df1.groupby('msg_type')['created_at'].count().compute()
# Out:
# msg_type
# 1     7814744
# 2       27027
# 3     1233067
# 4        2465
# 5      166550
# 18     478758
# 24     150028
# 27     115804
# Name: created_at, dtype: int64

# %%
df2.groupby('msg_type')['created_at'].count().compute()
# Out:
# msg_type
# 1     12892839
# 2        51049
# 3      2004343
# 5       266900
# 18      648627
# 24      217080
# 27      380124
# 4            1
# Name: created_at, dtype: int64

# %%
df3.groupby('msg_type')['created_at'].count().compute()
# Out:
# msg_type
# 1     20707583
# 2        78076
# 3      3237410
# 4         2466
# 5       433450
# 18     1127385
# 24      367108
# 27      495928
# Name: created_at, dtype: int64

# %%
df3.to_csv("s3://wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv", index=False, single_file=False)
# Out:
# ['wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0000.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0001.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0002.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0003.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0004.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0005.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0006.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0007.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0008.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0009.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0010.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0011.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0012.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0013.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0014.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0015.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0016.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0017.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0018.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0019.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0020.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0021.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0022.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0023.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0024.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0025.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0026.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0027.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0028.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0029.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0030.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0031.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0032.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0033.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0034.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0035.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0036.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0037.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0038.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0039.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0040.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0041.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0042.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0043.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0044.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0045.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0046.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0047.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0048.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0049.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0050.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0051.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0052.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0053.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0054.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0055.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0056.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0057.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0058.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0059.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0060.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0061.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0062.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0063.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0064.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0065.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0066.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0067.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0068.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0069.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0070.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0071.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0072.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0073.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0074.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0075.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0076.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0077.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0078.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0079.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0080.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0081.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0082.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0083.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0084.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0085.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0086.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0087.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0088.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0089.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0090.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0091.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0092.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0093.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0094.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0095.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0096.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0097.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0098.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0099.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0100.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0101.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0102.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0103.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0104.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0105.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0106.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0107.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0108.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0109.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0110.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0111.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0112.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0113.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0114.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0115.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0116.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0117.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0118.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0119.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0120.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0121.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0122.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0123.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0124.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0125.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0126.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0127.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0128.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0129.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/
part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0918.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0919.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0920.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0921.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0922.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0923.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0924.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0925.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0926.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0927.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0928.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0929.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0930.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0931.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0932.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0933.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0934.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0935.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0936.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0937.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0938.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0939.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0940.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0941.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0942.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0943.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0944.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0945.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0946.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0947.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0948.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0949.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0950.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0951.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0952.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0953.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0954.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0955.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0956.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0957.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0958.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0959.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0960.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0961.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0962.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0963.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0964.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0965.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0966.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0967.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0968.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0969.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0970.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0971.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0972.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0973.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0974.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0975.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0976.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0977.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0978.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0979.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0980.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0981.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0982.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0983.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0984.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0985.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0986.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0987.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0988.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0989.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0990.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0991.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0992.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0993.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0994.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0995.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0996.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0997.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0998.part',
#  'wbgdecinternal-ntl/AIS_TMP/MAY2_PART_2019_2020.csv/0999.part',
#  ...]

# %%
#df = dd.read_csv(f"{PATH_BASE}/WorldBank_SAIS_globalAOI_20190101_20201231_*.csv", 
df = dd.read_csv(f"{PATH_BASE}/WorldBank_SAIS_globalAOI_20190430_20190507.csv", 
                 storage_options=STORAGE_OPTS, 
                 #include_path_column=True,
                 #blocksize='100mb',
                 #blocksize=None, # Specifying NONE aligns to the files 
                 parse_dates=[#'created_at', 
                              #'timestamp', 
                              #'eta'
                             ], # Don't parse dates - extra CPU
                 dtype= {'created_at': str,
                         'timestamp': str,
                         'mmsi': int,
                         'msg_type': int,
                         'latitude': float,
                         'longitude': float,
                         'speed': float,
                         'course': float,
                         'heading': float,
                         'rot': float,
                         'imo': float,
                         'name': str,
                         'call_sign': str,
                         'flag': str,
                         'draught': float,
                         'ship_and_cargo_type': float,
                         'length': float,
                         'width': float,
                         'eta': str,
                         'destination': str,
                         'status': float,
                         'maneuver': float,
                         'accuracy': float,
                         'collection_type': str,
                         'to_bow': float,
                         'to_stern': float,
                         'to_port': float,
                         'to_starboard': float})
df.head()

# %%
df.npartitions

# %%
may = df.loc[(df.timestamp >= '2019-05-01') & (df.timestamp < '2019-05-06'), :]
may.head()

# %%
#may = df.loc[(df.timestamp >= '2019-05-01') & (df.timestamp < '2019-05-03'), :]
may = df.loc[df.timestamp.str.contains("2019-05-01"), :]
may.head()

# %%
#df.loc[((df.longitude.notnull()) & (df.latitude.notnull()) & (df.mmsi == 247298800)), :].head(1000)

# %%
# %time
df_ship = df.loc[df.mmsi == 247298800, :]
df_ship.to_csv("s3://wbgdecinternal-ntl/AIS_TMP/MMSI_247298800.csv", index=False, single_file=True)

# %%
df_day = df.loc[df.timestamp.str.contains("-05-02"), :]
df_day = df_day.repartition(npartitions=df.npartitions // 6)

df_day.head()

# %%
#df_day = df.loc[df.timestamp.str.contains("-05-02"), :]
df_day.to_csv("s3://wbgdecinternal-ntl/AIS_TMP/MAY2_2019_PART.csv", index=False, single_file=False)

# %%
#df_day = df.loc[(df.timestamp >= '2020-12-15') & (df.timestamp < '2020-12-16'), :]

# %%
#df_day = df_day.set_index('timestamp')

# %%
#df.visualize()

# %%
df_day = df_day.repartition(npartitions=df.npartitions // 730)

# %%
df_day.npartitions

# %%
df.to_csv("s3://wbgdecinternal-ntl/AIS_TMP/MAY2.csv", index=False, single_file=True)
